# %%
# Dependencies
import pandas as pd
import sqlalchemy

# Store filepath in a variable
neighbour_file = "Real_acct_owner/real_neighborhood_code.csv"

# Read our Data file with the pandas library
neighbour_file_df = pd.read_csv(neighbour_file, encoding="ISO-8859-1")

neighbour_file_df
# Out:
#        Neighbourhood_Cd  Group_cd                                Description
# 0                  0.02    1801.0                            TEST CONDO NBHD
# 1                  0.50    1089.0                        VALUATION TEST NBHD
# 2                  1.00    4026.0               SETTLERS VILLAGE 1,1R/P  & 2
# 3                  1.01    4025.0  SETTLERS VILLAGE SEC. 3, 3R/P, 5 ,& 5 R/P
# 4                  1.04    4160.0                          VILLAGES ON GRANT
# 5                  1.05    4025.0                  LAKEVILLE SEC 1,2,4,5,6,7
# 6                  1.06    4160.0                      GRANT MEADOWS SEC 1,3
# 7                  1.07    4160.0  GRANT MEADOWS SEC 2,4 & TELGE RANCH SEC 1
# 8                  1.08    4160.0                        GRANT MEADOWS SEC 5
# 9                 10.00       0.0   ROLLING CREEK Commercial (DO NOT REMOVE)
# 10                10.01    4139.0                 ROLLING CREEK 1/GRAND OAKS
# ...

# %%
## dropping null value for Description

##neighbour_file_clean_df =neighbour_file_df.fillna(subset = ['Description'])
neighbour_file_clean_df.replace(to_replace = '  ', value ="Omega Warrior") 
neighbour_file_clean_df
# Out:
#        Neighbourhood_Cd  Group_cd                                Description
# 0                  0.02    1801.0                            TEST CONDO NBHD
# 1                  0.50    1089.0                        VALUATION TEST NBHD
# 2                  1.00    4026.0               SETTLERS VILLAGE 1,1R/P  & 2
# 3                  1.01    4025.0  SETTLERS VILLAGE SEC. 3, 3R/P, 5 ,& 5 R/P
# 4                  1.04    4160.0                          VILLAGES ON GRANT
# 5                  1.05    4025.0                  LAKEVILLE SEC 1,2,4,5,6,7
# 6                  1.06    4160.0                      GRANT MEADOWS SEC 1,3
# 7                  1.07    4160.0  GRANT MEADOWS SEC 2,4 & TELGE RANCH SEC 1
# 8                  1.08    4160.0                        GRANT MEADOWS SEC 5
# 9                 10.00       0.0   ROLLING CREEK Commercial (DO NOT REMOVE)
# 10                10.01    4139.0                 ROLLING CREEK 1/GRAND OAKS
# ...

# %%
## creating output file without null value for description
neighbour_file_clean_df.to_csv("Real_acct_owner/neighbour_file_clean.csv", index=False, header=True)

# %%
## connection for Mysql
engine = sqlalchemy.create_engine('mysql+pymysql://root:root@localhost:3306/hcad')

## reading file to insert into mysql
neighbour_file_ins =  pd.read_csv('Real_acct_owner/neighbour_file_clean.csv', encoding='latin-1',usecols=['Neighbourhood_Cd', 'Group_cd','Description'])

##inserting data into mysql
neighbour_file_ins.to_sql('neighbourhood', con=engine, if_exists='append',index=False,chunksize=1)
