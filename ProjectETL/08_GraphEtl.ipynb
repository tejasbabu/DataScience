# %%
import pandas as pd
import sqlalchemy
import cx_Oracle
import matplotlib.pyplot as plt
# %matplotlib notebook
import numpy

# %%
#defining mysql connection

engine = sqlalchemy.create_engine('mysql+pymysql://root:root@localhost:3306/hcad')

# %%
value_city_df  = pd.read_sql('select * from investment;',engine)
value_city_df =value_city_df.set_index('city')
value_city_df
# Out:
#                     Value
# city
# ATLANTA         169.59539
# BELLAIRE       2729.74116
# BIRMINGHAM      140.65025
# BOSTON          310.56800
# CHARLESTON      285.97920
# CHICAGO         705.12312
# DALLAS         1193.23028
# FORT WORTH      419.65955
# GREENWICH       351.27610
# HALLANDALE      417.83300
# IRVING          209.25096
# KATY            172.87079
# LA PORTE        177.19364
# LAS VEGAS       148.44260
# LEXINGTON       189.37800
# PHILADELPHIA    324.91660
# SAN FRANCISCO   689.83032
# SAN RAMON       293.52050
# SCOTTSDALE      754.56000
# SPRING          155.91969
# SUGAR LAND      283.93007

# %%
value_city_df.plot(kind="bar", figsize=(8,4), fontsize=10)
# Set a title for the chart
plt.title("Investment From Other City of US in Houston (in 100000)" ,  fontsize=10)
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
value_zipcode_df  = pd.read_sql('select * from assesssedvalue;',engine)
value_zipcode_df =value_zipcode_df.set_index('zipcode')
value_zipcode_df
# Out:
#             sum(Assessed_value)/100000
# zipcode
# 19102-2516                  1460.15008
# 33009-4373                  1117.71352
# 60611-5518                  3561.67470
# 75240-2306                  4760.07328
# 77001-0285                  7655.32365
# 77002-2755                  3660.56484
# 77002-3009                  4830.77312
# 77002-4372                  8283.37900
# 77002-6336                  2969.35520
# 77002-6761                  3072.62984
# 77002-6929                  1310.61426
# 77007-8259                  1399.15296
# 77027-3019                  1865.40867
# 77056-6100                  2337.22688
# 77056-6178                  2313.80704
# 77210-4018                  8370.59223
# 77210-4372                  2532.57892
# 77251-1308                  2114.04992
# 77251-1475                  3029.68324
# 85261-4900                  5218.96768
# 94105-1131                  1988.83664

# %%
value_zipcode_df.plot(kind="bar", figsize=(8,4), fontsize=10)
# Set a title for the chart
plt.title("List of Zip code with highest Assessed value in Houston (in 100000000)" ,  fontsize=10)
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
value_appraised_df  = pd.read_sql('select * from appraisedvalue;',engine)
value_appraised_df =value_appraised_df.set_index('city')
value_appraised_df
# Out:
#              sum(APPRAISED_VALUE)
# city
# BAYTOWN                13155.2161
# CHANNELVIEW             8253.5299
# CROSBY                  2511.1608
# CYPRESS                 4868.4471
# DEER PARK              14002.9241
# FRIENDSWOOD             1663.2169
# GALENA PARK             5962.5870
# HUMBLE                  8188.3033
# KATY                    8783.4181
# LA PORTE               23182.3399
# PASADENA               39410.7853
# SEABROOK                4670.8856
# SPRING                  8059.9801
# TOMBALL                 5943.3353
# WALLER                  3782.9986
# WEBSTER                 3159.8428

# %%
value_appraised_df.plot(kind="bar", figsize=(8,4), fontsize=10)
# Set a title for the chart
plt.title("List of City  with highest Appraised value in HCAD except Houston (in 100000)" ,  fontsize=10)
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">
